# %%
import pandas as pd
df = pd.read_csv("cleanedfile.csv")
df
# Out:
#       Z-Score_charges  Z-Score_children  Z-Score_bmi  Z-Score_age        age  \
# 0            0.416681         -1.215522    -0.486360    -1.566362  19.000000
# 1           -1.954790         -0.627907     0.560813    -1.644660  18.000000
# 2           -1.118771          0.547324     0.418823    -0.861676  28.000000
# 3            0.416681         -1.215522    -1.409293    -0.470184  33.000000
# 4           -1.297582         -1.215522    -0.308873    -0.548482  32.000000
# ...               ...               ...          ...          ...        ...
# 4239         0.416681         -0.040291     0.868214     0.312801  43.000000
# 4240         0.416681          1.134940    -0.419173    -0.597485  31.374148
# 4241         1.000919          1.134940    -0.687578     0.889919  50.370750
# 4242         0.948772          1.134940     0.134283     0.798382  49.201678
# 4243         0.416681         -1.215522     0.046100     0.782591  49.000000
#
# ...

# %%
import matplotlib.pyplot as plt

features = ['sex','children','smoker']
plt.subplots(figsize=(20,10))
for i,col in enumerate(features):
    plt.subplot(2,2,i+1)
    df.groupby(col).mean()['charges'].plot.bar()
plt.show()

# %%
# Step 1: Group the DataFrame by the specified column
grouped_data = df.groupby(col)

# Step 2: Calculate the mean of the 'charges' column for each group
mean_charges_per_group = grouped_data['charges'].mean()
mean_charges_per_group
# Step 3: Create a bar plot using the calculated mean values
# mean_charges_per_group.plot(kind='bar')
# Out:
# smoker
# 0    7692.731639
# 1    9510.929370
# Name: charges, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating a sample DataFrame
data = {'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
        'Charges': [100, 150, 120, 200, 180, 220]}

df = pd.DataFrame(data)

# Step 1: Group the DataFrame by the 'Category' column
grouped_data = df.groupby('Category')

# Step 2: Calculate the mean of the 'Charges' column for each group
mean_charges_per_group = grouped_data['Charges'].mean()

# Plotting the mean charges for each category
mean_charges_per_group.plot(kind='bar', color='skyblue')
plt.title('Mean Charges for Each Category')
plt.xlabel('Category')
plt.ylabel('Mean Charges')
plt.show()
